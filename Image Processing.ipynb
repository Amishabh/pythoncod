# %%
from PIL import Image
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
import matplotlib.image as mpimg
import cv2
from matplotlib import pyplot as plt
from six.moves import xrange

# %%
image = Image.open('road.jpg')

# %%
image.show() #It will show imagne in my Latop with image viewer

# %%
plt.imshow(image) #it will print the image

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.002, 0.001, 0.003])

img = mpimg.imread('road.jpg')     
gray = rgb2gray(img)    
plt.imshow(gray, cmap=plt.get_cmap('gray'), vmin = 0, vmax = 1)
plt.show()

# %%
image = cv2.imread(r'C:\Users\vkvku\Desktop\Python\road.jpg') 
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow("Grayscale Image", gray)

# %%
plt.imshow(gray)

# %%
cv2.imwrite('C:\\Users\\vkvku\\Desktop\\Python\\converted.jpg', img_gray)
# Out:
# True

# %%
blur = cv2.GaussianBlur(img,(5,5),0)

# %%
plt.show()

# %%
plt.imshow(blur)

# %%
img = cv2.imread('road.jpg',0)
img = cv2.medianBlur(img,5)

# %%
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)

# %%
titles = ['Original Image', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2]

# %%
for i in xrange(2):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
